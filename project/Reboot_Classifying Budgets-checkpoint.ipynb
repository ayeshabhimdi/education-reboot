# %% [markdown]
# # Project Details:
#
# * Title:
# * Team Members:

# %% [markdown]
# # Introduction
#
# The **Reboot: Box-Plots for Education** is a data science challenge sponsored by the Education Resource Strategies (ERS). It is an on-going competition which will end in February.
#
# In this project, we plan to solve a **multi-class-multi-label classification problem** with the goal of attaching canonical labels to the freeform text in budget line items. These labels let ERS understand how schools are spending money and tailor their strategy recommendations to improve outcomes for students, teachers, and administrators.

# %% [markdown]
# ## Project Problem
# Predict the probability that a certain label from each target category is attached to a budget line item.

# %% [markdown]
# ## Features Description
# Train data set, "train.csv" has 25 features. Out of these, 2 are numerical and rest are categorical. Also out of 25, 9 are target features.
#
# Following are the features that will be used for building model and predicting probabilities.
#
# * FTE float - If an employee, the percentage of full-time that the employee works.
# * Facility_or_Department - If expenditure is tied to a department/facility, that  department/facility.
# * Function_Description - A description of the function the expenditure was serving.
# * Fund_Description - A description of the source of the funds.
# * Job_Title_Description - If this is an employee, a description of that employee's job title.
# * Location_Description - A description of where the funds were spent.
# * Object_Description - A description of what the funds were used for.
# * Position_Extra - Any extra information about the position that we have.
# * Program_Description - A description of the program that the funds were used for.
# * SubFund_Description - More detail on Fund_Description
# * Sub_Object_Description - More detail on Object_Description
# * Text_1 - Any additional text supplied by the district.
# * Text_2 - Any additional text supplied by the district.
# * Text_3 - Any additional text supplied by the district.
# * Text_4 - Any additional text supplied by the district.
# * Total float - The total cost of the expenditure.
#
#
# And these are target features we have to predict probability for labeling each row.
#
# * Function
# * Object_Type
# * Operating_Status
# * Position_Type
# * Pre-K
# * Reporting
# * Sharing
# * Student_type
# * Use

# %% [markdown]
# # ETL Phase

# %% [markdown]
# ## Prepare the notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sys
import seaborn as sns
import warnings
warnings.simplefilter('ignore')

from collections import Counter
from scipy import sparse, stats
from sklearn import preprocessing as prep
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import train_test_split, GridSearchCV, ShuffleSplit, StratifiedKFold
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.preprocessing import Imputer, LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.utils import check_array
from time import time

# %matplotlib inline

# %%
# %ls -l data/education_reboot/TrainingData.csv
# Out:
# -rwxrwxrwx 1 root root 124760056 Nov 10 22:05 data/education_reboot/TrainingData.csv*

# %%
path = os.path.join('data','education_reboot') #make sure you have the same path in your parent directory
path
# Out:
# 'data/education_reboot'

# %%
def load_data(datapath,data):
    csv_path = os.path.join(datapath,data)
    df = pd.read_csv(csv_path,index_col=0)
    print(df.info())
    display(df.head())
    print()
    return df

# %% [markdown]
# ## Exploratory Data Analysis

# %%
train = load_data(path,"TrainingData.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400277 entries, 134338 to 415831
# Data columns (total 25 columns):
# Function                  400277 non-null object
# Use                       400277 non-null object
# Sharing                   400277 non-null object
# Reporting                 400277 non-null object
# Student_Type              400277 non-null object
# Position_Type             400277 non-null object
# Object_Type               400277 non-null object
# Pre_K                     400277 non-null object
# Operating_Status          400277 non-null object
# Object_Description        375493 non-null object
# Text_2                    88217 non-null object
# SubFund_Description       306855 non-null object
# Job_Title_Description     292743 non-null object
# Text_3                    109152 non-null object
# Text_4                    53746 non-null object
# Sub_Object_Description    91603 non-null object
# Location_Description      162054 non-null object
# FTE                       126071 non-null float64
# Function_Description      342195 non-null object
# Facility_or_Department    53886 non-null object
# Position_Extra            264764 non-null object
# Total                     395722 non-null float64
# Program_Description       304660 non-null object
# Fund_Description          202877 non-null object
# Text_1                    292285 non-null object
# dtypes: float64(2), object(23)
# memory usage: 79.4+ MB
# None
#                        Function          Use          Sharing Reporting  \
# 134338     Teacher Compensation  Instruction  School Reported    School
# 206341                 NO_LABEL     NO_LABEL         NO_LABEL  NO_LABEL
# 326408     Teacher Compensation  Instruction  School Reported    School
# 364634  Substitute Compensation  Instruction  School Reported    School
# 47683   Substitute Compensation  Instruction  School Reported    School
#
#        Student_Type Position_Type               Object_Type     Pre_K  \
# 134338     NO_LABEL       Teacher                  NO_LABEL  NO_LABEL
# 206341     NO_LABEL      NO_LABEL                  NO_LABEL  NO_LABEL
# 326408  Unspecified       Teacher  Base Salary/Compensation  Non PreK
# 364634  Unspecified    Substitute                  Benefits  NO_LABEL
# 47683   Unspecified       Teacher   Substitute Compensation  NO_LABEL
#
#          Operating_Status            Object_Description  \
# 134338  PreK-12 Operating                           NaN
# 206341      Non-Operating           CONTRACTOR SERVICES
# 326408  PreK-12 Operating  Personal Services - Teachers
# 364634  PreK-12 Operating             EMPLOYEE BENEFITS
# 47683   PreK-12 Operating  TEACHER COVERAGE FOR TEACHER
#
#                     ...               Sub_Object_Description  \
# 134338              ...                                  NaN
# 206341              ...                                  NaN
# 326408              ...                                  NaN
# 364634              ...                                  NaN
# 47683               ...                                  NaN
#
#        Location_Description  FTE     Function_Description  \
# 134338                  NaN  1.0                      NaN
# 206341                  NaN  NaN                 RGN  GOB
# 326408                  NaN  1.0                      NaN
# 364634                  NaN  NaN  UNALLOC BUDGETS/SCHOOLS
# 47683                   NaN  NaN              NON-PROJECT
#
#        Facility_or_Department              Position_Extra      Total  \
# 134338                    NaN               KINDERGARTEN   50471.810
# 206341                    NaN                UNDESIGNATED   3477.860
# 326408                    NaN                     TEACHER  62237.130
# 364634                    NaN  PROFESSIONAL-INSTRUCTIONAL     22.300
# 47683                     NaN  PROFESSIONAL-INSTRUCTIONAL     54.166
#
#                    Program_Description        Fund_Description  \
# 134338                    KINDERGARTEN            General Fund
# 206341   BUILDING IMPROVEMENT SERVICES                     NaN
# 326408           Instruction - Regular  General Purpose School
# 364634  GENERAL MIDDLE/JUNIOR HIGH SCH                     NaN
# 47683    GENERAL HIGH SCHOOL EDUCATION                     NaN
#
#                                Text_1
# 134338                            NaN
# 206341  BUILDING IMPROVEMENT SERVICES
# 326408                            NaN
# 364634            REGULAR INSTRUCTION
# 47683             REGULAR INSTRUCTION
#
# [5 rows x 25 columns]

# %% [markdown]
# Looking at the column names i.e. our features, we see there are **Two** numeric features, FTE and TOTAL.
#
# * FTE stands for full-time equivalent(0-100%). To elaborate, if a budget item is associated to an employee, then we have a value between 0 and 1. It tells us the percentage of full-time that the employee works. A value of 1 means the employee works full-time. A value close to 0 means the employee is working either part-time or on contract basis.
#
# * TOTAL stands for the total cost of the expenditure. It tells us how much the budget item costs.
#
# **Let's explore them further:**

# %%
train.describe()
# Out:
#                  FTE         Total
# count  126071.000000  3.957220e+05
# mean        0.426794  1.310586e+04
# std         0.573576  3.682254e+05
# min        -0.087551 -8.746631e+07
# 25%         0.000792  7.379770e+01
# 50%         0.130927  4.612300e+02
# 75%         1.000000  3.652662e+03
# max        46.800000  1.297000e+08

# %% [markdown]
# We see there are some negative values in the the numeric features. We would have to impute such missing or incorrect values as we cannot have a negative value associated with the percentage of full-time that the employee works or total cost of the expenditure.

# %% [markdown]
# ## Distribution of Categorical Features
# Since this data set primarily consists of categorical features, it is very important to
# look at their distribution.
# The table below show unique values, count of features, top feature and frequency of top
# subcategory under each category.

# %%
train.describe(include=['O'])
# Out:
#                     Function          Use          Sharing Reporting  \
# count                 400277       400277           400277    400277
# unique                    37            8                5         3
# top     Teacher Compensation  Instruction  School Reported    School
# freq                   86354       203608           254433    257258
#
#        Student_Type Position_Type               Object_Type     Pre_K  \
# count        400277        400277                    400277    400277
# unique            9            25                        11         3
# top     Unspecified       Teacher  Base Salary/Compensation  NO_LABEL
# freq         223026        102788                     97670    306425
#
#          Operating_Status Object_Description         ...            Text_3  \
# count              400277             375493         ...            109152
# unique                  3                602         ...                34
# top     PreK-12 Operating  EMPLOYEE BENEFITS         ...           Regular
# freq               343578              47495         ...             94462
#
#                      Text_4                         Sub_Object_Description  \
# count                 53746                                          91603
# unique                  244                                            182
# top     Regular Instruction  Extra Duty Pay/Overtime For Support Personnel
# freq                  10762                                           9159
#
#        Location_Description Function_Description Facility_or_Department  \
# count                162054               342195                  53886
# unique                  354                  687                    179
# top                 School           NON-PROJECT     All Campus Payroll
# freq                  65524                76890                  17697
#
#                     Position_Extra           Program_Description  \
# count                       264764                        304660
# unique                         580                           421
# top     PROFESSIONAL-INSTRUCTIONAL  GENERAL ELEMENTARY EDUCATION
# freq                         92136                         32829
#
#               Fund_Description               Text_1
# count                   202877               292285
# unique                     141                 1405
# top     General Operating Fund  REGULAR INSTRUCTION
# freq                     33467                64896
#
# [4 rows x 23 columns]

# %%
plt.hist(train['FTE'].dropna(),range=[0,1])
plt.title('Distribution of %full-time \n employee works')
plt.xlabel('% of full-time')
plt.ylabel('num employees')
plt.show()

# %% [markdown]
# From the above plot, we can see that our budgets data favors part-time and contract-based employees as we have more contract employees than full-time employees.
#
# We can assume that contract-based employees are hired for a short-term purpose and that is why they need certain items more frequent than full-time employees who would have such items easily accessible. (NEED to INFER something!)

# %%
train['Function'].value_counts()
# Out:
# Teacher Compensation                               86354
# Substitute Compensation                            62215
# NO_LABEL                                           59579
# Aides Compensation                                 19858
# Instructional Materials & Supplies                 19711
# Facilities & Maintenance                           19617
# Professional Development                           19102
# Student Transportation                             14371
# Food Services                                      14203
# School Administration                              13055
# Enrichment                                         10686
# Extended Time & Tutoring                            8375
# Curriculum Development                              7603
# Physical Health & Services                          5929
# Social & Emotional                                  5003
# Library & Media                                     4522
# Special Population Program Management & Support     4403
# Data Processing & Information Services              3241
# Career & Academic Counseling                        2891
# Security & Safety                                   2812
# School Supervision                                  2687
# Finance, Budget, Purchasing & Distribution          2261
# Parent & Community Relations                        2157
# Utilities                                           1904
# Other Non-Compensation                              1803
# Research & Accountability                           1416
# Human Resources                                     1319
# Other Compensation                                   769
# Governance                                           631
# Recruitment                                          513
# Untracked Budget Set-Aside                           357
# Student Assignment                                   338
# Communications                                       296
# Legal                                                117
# Development & Fundraising                             93
# Insurance                                             57
# Facilities Planning                                   29
# Name: Function, dtype: int64

# %%
train['Use'].value_counts()
# Out:
# Instruction                    203608
# NO_LABEL                        78712
# O&M                             45868
# ISPD                            26118
# Pupil Services & Enrichment     23779
# Leadership                      15715
# Business Services                6120
# Untracked Budget Set-Aside        357
# Name: Use, dtype: int64

# %%
train['Object_Type'].value_counts()
# Out:
# Base Salary/Compensation       97670
# Benefits                       85467
# NO_LABEL                       69644
# Other Compensation/Stipend     61685
# Supplies/Materials             31935
# Substitute Compensation        27357
# Contracted Services             7512
# Other Non-Compensation          6297
# Travel & Conferences            5030
# Equipment & Equipment Lease     4460
# Rent/Utilities                  3220
# Name: Object_Type, dtype: int64

# %%
train['Fund_Description'].value_counts()
# Out:
# General Operating Fund                                  33467
# General Fund                                            29036
# GENERAL FUND                                            28176
# General Purpose School                                  20333
# Title I - Disadvantaged Children/Targeted Assistance    19967
# General                                                  7877
# "Title  Part A Improving Basic Programs"                 6885
# Special Trust                                            6335
# School Federal Projects                                  5424
# FED THRU STATE-CASH ADVANCE                              3544
# National School Breakfast And Lunch Program              3405
# School Nutrition Service Fund                            2538
# CONVERSION CHARTER SCHOOLS                               2264
# Campus Activity Funds                                    2241
# LOCAL FUND                                               2202
# FOOD SERVICES                                            1780
# Title I                                                  1684
# Capital Projects Fund                                    1617
# Schoolwide Schools                                       1614
# Idea Part B Formula                                      1575
# Miscellaneous Federal Grants                             1259
# Special Education                                        1239
# MILLAGE                                                  1216
# ITEMFA Schools Partnership                               1179
# Title  School Improvement Stimulus G                     1072
# Miscellaneous State Grants                                928
# Intensive Reading Instruction Initiative Grant            900
# Title Iii Part A - Lep                                    861
# Food Services                                             836
# Auxiliary Services                                        759
#                                                         ...
# ENERGY MANAGEMENT                                           5
# Title Ii Part D Subpart  Enhancing Education Thro           5
# "Title II, Part D                                           4
# ARRA Grants (Not Including Stabilization Grants)            4
# Title Iv Part A Safe & Drug Free Schools                    4
# PRIVATE GRANT FUND                                          4
# "Title  Part A ARRA                                         4
# Title II D - Technology                                     4
# Bond Retirement                                             4
# Employee Benefits Self-Insurance                            3
# Idea C Early Intervention                                   3
# MAINTENANCE - CHARTERS                                      3
# Liability Self-Insurance                                    2
# Fixed Asset Conversion                                      2
# Key Gov't Finance-CISCO VOIP                                2
# Department of Human Resources                               2
# Principal Accounts-Activity Funds                           1
# CTAE Extended Day or Extended Year - State Grant            1
# HHS Aids Education                                          1
# Building                                                    1
# SPECIAL ACT BONDS                                           1
# IMPACT FEES                                                 1
# Basic Skills Programs For High School Students / H          1
# Principal Accounts-Governmental Funds                       1
# TRUST FUND                                                  1
# EDUCATION JOBS FUND                                         1
# LOCAL AND PRIVATE GRANT                                     1
# FLEXIBLE SPENDING ACCOUNT                                   1
# CO & DS                                                     1
# TITLE IV                                                    1
# Name: Fund_Description, Length: 141, dtype: int64

# %%
train['SubFund_Description'].value_counts()
# Out:
# GENERAL FUND                                   123327
# Operations                                      26895
# FEDERAL GDPG FUND - FY                          13562
# Support Services - Instructional Staff          10238
# Special Instruction                             10106
# DISTRICT SPECIAL REVENUE FUNDS                   9975
# LOCAL                                            9393
# ARRA - STIMULUS                                  7458
# Community Services                               7386
#  MILL LEVY                                       5964
# FOOD SERVICE FUND                                5810
# MISCELLANEOUS                                    5649
# "Title  Part A Improving Basic Programs"         5260
# PRIMARY GRADES PROGRAM                           4379
# ITEMGD PRESCHOOL PROGRAM                         3584
# LEVY OVERRIDE                                    3267
# Regular Instruction                              3071
# Child Nutrition                                  2558
# State Ed. Allotment                              2427
# SUMMER ED, ARTS & SPORTS - SEAS                  2249
# MEDIA CENTERS                                    2063
# CAPITAL RESERVE FUND                             2059
# Support Services--Pupils                         2035
# FEDERAL GDPG FUND                                2009
# SCHOOL NUTRITION SERVICE                         1858
# Operation and Maintenance of Plant Services      1834
# HIGH SCHOOL GENERAL ED PROGRAM 9-12              1795
# Support Services - Administration                1717
# SCHOOL-WIDE SCHOOL PGMS FOR TITLE GRANTS         1501
# MIDDLE SCHOOL PROGRAM 6-8                        1466
#                                                 ...
# MOVE ON WHEN READY                                  1
# CAREER TECH - EXTENDED DAY/TECH CAREEER             1
# CAFETERIA                                           1
# AFTERSCHOOL SNACK AND SUPPER PROGRAM                1
# NATIONAL SCHOOL BREAKFAST                           1
# NATIONAL SCHOOL LUNCH                               1
# SUMMER FOOD SERVICE PROGRAM                         1
#  Support for Homeless Education                     1
# TRANSFERS - OUT *                                   1
# DEPARTMENT OF PUBLIC WORKS                          1
# SWING SPACE SERVICE - DOT                           1
# SCHOOL ACTIVITY FUNDS                               1
# CONTROL FUND                                        1
# TITLE I-A SCHOOL IMPROVEMENT GRANT -ARRA            1
# PROFESSIONAL DEV SCHOOLS-IMPROV OF INSTR            1
# Reimbursement for Healthly Schools Act              1
# After School Snack and Supper Programs              1
# FRESH FRUIT & VEGRTABLES PROGRAM                    1
# STIMULUS                                            1
# Golf Tournament                                     1
# NONRESIDENT                                         1
# PRINCIPAL ACCOUNTS - GOVERNMENTAL FUND              1
# DOLLAR GENERAL LITERACY FOUNDATION                  1
# CHARITABLE & EDUCATIONAL FOUNDAT                    1
# ALTERNATIVE EDUCATION PROGRAM, LOCAL                1
# EDUCATION OF HIV/AIDS                               1
# PROFESSIONAL DEV                                    1
# TITLE IV-A - ADMINISTRATION                         1
# STATE REVENUE MATCH                                 1
# FOUNDATION                                          1
# Name: SubFund_Description, Length: 274, dtype: int64

# %%
train['Sub_Object_Description'].value_counts()
# Out:
# Extra Duty Pay/Overtime For Support Personnel         9159
# Certificated Employees Salaries And Wages             8720
# Salaries And Wages For Teachers And Other Professi    7285
# Salaries And Wages For Substitute Teachers            6327
# General Supplies *                                    5829
# Salaries Or Wages For Support Personnel               4824
# Supplies And Materials                                3195
# Extended Day                                          3045
# Extra Duty Wages                                      2730
# Purchased Services                                    2534
# Professional And Technical Services *                 2392
# General Supplies                                      2280
# Personal Services - Employees Salaries And Wages      2257
# Non-Certificated Salaries And Wages                   2015
# Extended Week                                         1828
# Extended Year                                         1545
# Equipment *                                           1535
# Critical Needs Incentive                              1531
# Textbooks *                                           1282
# Teacher Retirement                                    1177
# Contracted Craft Or Trade Services *                  1177
# Temporary / Part-Time Support Personnel               1065
# Travel Mileage/Meeting Expense *                      1052
# Awards And Prizes *                                    899
# Other Objects                                          866
# Property Services (Other Than Utilities) *             818
# Capital Outlay                                         802
# Travel Allowances                                      686
# Pupil Transportation *                                 678
# Fees (Not Associated With Travel)                      600
#                                                       ...
# Inventory Adjustment / Broken Item Adjustment            1
# Inventory Adjustment / Quantity / Cost Decrease Ad       1
# Tax Appraisal And Collection                             1
# Series  Variable Rate Building Bonds                     1
# Inventory Adjustment / Physical Inventory Count Ad       1
# Travel And Subsistence - Non-Employees                   1
# Substitutes For Support Personnel                        1
# Inventory Adjustment / Quantity / Cost Increase Ad       1
# Reclassified Transportation Expenditures/Expense         1
# Land *                                                   1
# Capital Lease Principal                                  1
# Payments To Tax Increment Fund                           1
# Inventory Adjustment / Initial Conversion Adjustme       1
# Student Tuition - Other Than Public Schools              1
# Retainage                                                1
# Operating Transfers Out                                  1
# PROFESSIONAL AND TECHNICAL SERVICES *                    1
# Travel And Subsistence - Board Members                   1
# Student Tuition - Public Schools                         1
# Improvements Other Than Buildings *                      1
# Retention Incentives                                     1
# TEXTBOOKS *                                              1
# Arbitrage                                                1
# Inventory Adjustment / Disposal Of Obsolete Item A       1
# Transfers And Contingencies *                            1
# Other Uses                                               1
# Land Purchase And Improvement                            1
# Interest On Capital Lease                                1
# DUES AND FEES *                                          1
# Rentals - Land, Buildings And Grounds                    1
# Name: Sub_Object_Description, Length: 182, dtype: int64

# %%
train['Object_Description'].value_counts()
# Out:
# EMPLOYEE BENEFITS                                                     47495
# SALARIES OF PART TIME EMPLOYEE                                        31761
# SALARIES OF REGULAR EMPLOYEES                                         24319
# CONTRA BENEFITS                                                       19381
# Salaries And Wages For Teachers And Other Professi                    18632
# ADDITIONAL/EXTRA DUTY PAY/STIP                                        16841
# SUPPLIES                                                              13117
# RETIREMENT CONTRIB.                                                   13073
# Regular *                                                              9270
# Extra Duty Pay/Overtime For Support Personnel                          9159
# EMPLOYER PD MED CONTRIBUTION                                           8617
# OTHER PERSONAL SERVICES                                                8326
# Personal Services - Teachers                                           7685
# Personal Services - Substitute Teachers Certified                      7254
# Salaries And Wages For Substitute Professionals                        6672
# Salaries Or Wages For Support Personnel                                5890
# SUPPLIES                                                               3539
# BONUSES                                                                3369
# OTHER SUPPORT PERSONNEL                                                3354
# CLASSROOM TEACHER                                                      3304
# Supplies and Materials                                                 3273
# WORKSHOP PARTICIPANT                                                   3268
# General Supplies                                                       3265
# Personal Services - Other Compensation                                 3200
# PURCHASE OF EQUIPMENT-OTHER THAN BUSES AND COMPUTE                     2982
# GENERAL SUPPLIES                                                       2786
# Personal Services - Education Assistants                               2717
# Classroom Supplies                                                     2607
# Purchased Services                                                     2534
# SALARIES FOR OVERTIME                                                  2522
#                                                                       ...
# Safety and Law Enforcement Supplies                                       1
# FEES                                                                      1
# Shipping and Freight Charges                                              1
# RENTALS - OTHER                                                           1
# TRANSFERS TO ENTERPRISE FUNDS                                             1
# Other Professional Services                                               1
# FILMS PURCHASED                                                           1
# GAS                                                                       1
# ELECTION FEES                                                             1
# TRANS CHARGES - MATERIALS                                                 1
# FUEL AUTOMOTIVE                                                           1
# JUDGEMENTS, INDEMNITIES                                                   1
# CLEANING SUPPLIES                                                         1
# PURCHASED PROFESSIONAL AND TECH SVCS-ACTUARY                              1
# TUITION                                                                   1
# Other Materials  and Supplies                                             1
# *******SUSPENSE*******                                                    1
# FUEL - HEATING                                                            1
# Benefits and Claims                                                       1
# Internet Access Service                                                   1
# Operating Transfers Out                                                   1
# AUTO ALLOWANCE                                                            1
# CLEANING/CHEMICAL SUPPLIES                                                1
# SECONDARY COUNSELOR                                                       1
# Land Purchase And Improvement                                             1
# Fidelity Bond Premiums                                                    1
# COST OF GOOD SOLD                                                         1
# RESERVE                                                                   1
# SOFTWARE                                                                  1
# Student Transportation Purchased from a District Outside the State        1
# Name: Object_Description, Length: 602, dtype: int64

# %%
## Let's Look at null values under each category

print(train.isnull().sum())
# Out:
# Function                       0
# Use                            0
# Sharing                        0
# Reporting                      0
# Student_Type                   0
# Position_Type                  0
# Object_Type                    0
# Pre_K                          0
# Operating_Status               0
# Object_Description         24784
# Text_2                    312060
# SubFund_Description        93422
# Job_Title_Description     107534
# Text_3                    291125
# Text_4                    346531
# Sub_Object_Description    308674
# Location_Description      238223
# FTE                       274206
# Function_Description       58082
# Facility_or_Department    346391
# Position_Extra            135513
# Total                       4555
# Program_Description        95617
# Fund_Description          197400
# Text_1                    107992
# dtype: int64

# %%
average_total=train[['Total', 'Function']].groupby(['Function'], as_index = True).mean().sort_values(by = 'Total')
sns.set(style="darkgrid")
sns.barplot(average_total.index, average_total.values, alpha=0.9)
plt.title('Distribution of Total')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Function', fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-37-5a7aa1e5f944> in <module>()
#       1 average_total=train[['Total', 'Function']].groupby(['Function'], as_index = True).mean().sort_values(by = 'Total')
#       2 sns.set(style="darkgrid")
# ----> 3 sns.barplot(average_total.index, average_total.values, alpha=0.9)
#       4 plt.title('Distribution of Total')
#       5 plt.ylabel('Number of Occurrences', fontsize=12)
#
# /opt/conda/lib/python3.5/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# /opt/conda/lib/python3.5/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# /opt/conda/lib/python3.5/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     205                 # Group the numeric data
#     206                 plot_data, value_label = self._group_longform(vals, groups,
# --> 207                                                               group_names)
#     208
#     209                 # Now handle the hue levels for nested ordering
#
# /opt/conda/lib/python3.5/site-packages/seaborn/categorical.py in _group_longform(self, vals, grouper, order)
#     244         # Ensure that the groupby will work
#     245         if not isinstance(vals, pd.Series):
# --> 246             vals = pd.Series(vals)
#     247
#     248         # Group the val data
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     273             else:
#     274                 data = _sanitize_array(data, index, dtype, copy,
# --> 275                                        raise_cast_failure=True)
#     276
#     277                 data = SingleBlockManager(data, index, fastpath=True)
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    4163     elif subarr.ndim > 1:
#    4164         if isinstance(data, np.ndarray):
# -> 4165             raise Exception('Data must be 1-dimensional')
#    4166         else:
#    4167             subarr = com._asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional

# %%
average_total =train[['Total', 'Job_Title_Description']].groupby(['Job_Title_Description'], as_index = True).mean().sort_values(by = 'Total')
average_total
# Out:
#                                                      Total
# Job_Title_Description
# Dir, Library Media Svcs                         -38.695000
# TCHR, K-8 SUB DAY/DAY                            -0.580000
# INT TEMP EXEC SEC TO THE CEO                     -0.550000
# SUBSTITUTE GENERAL PREP                          -0.330000
# CLASSIFIED EDUC CONSUL II                        -0.280000
# EDUCATIONAL ASSISTANT, RETIREE                   -0.280000
# SECURITY OFFICER (EXTERNAL)                      -0.247500
# TCHR, K-8 LDBD TUTOR-HRLY                        -0.162500
# ASSOC STRATEGIC IMPLEM OFFICER                    0.220000
# CERT ED CONSLT II, RETIREE                        0.285000
# TCHR, SCNDY LDBD TUTOR-HRLY                       0.545000
# Sub Manager, Food Service                         0.720000
# Substitute School Resource Officer               21.680000
# Data Assessment Partner                          33.845000
# LLI Coach                                        35.472000
# Mild/Moderate/Comm Asst                          44.025000
# Middle School Athletics                          46.979037
# Business Process Coord                           51.602658
# AIDE (SP.ED.) EXTENDED YEAR                      64.780000
# TEACHER POOL, UNASSIGNED                         83.013987
# Summer Lunchroom Monitor                         93.973416
# Application Processing Rep                      124.016400
# Teacher, Short Term Sub                         124.299042
# School Counselor                                178.646600
# Teacher,Retrd Shrt Term Sub                     182.909364
# TUTOR,TEMPORARY                                 186.249304
# CLERICAL, TEMPORARY                             199.575415
# Pre-School Aide                                 241.214182
# SUB TEACHER-MIDDLE/HIGH                         257.839355
# TO BE DISCHARGED                                263.268148
# ...                                                    ...
# PRINCIPAL SECETARY                           245487.666200
# CHIEF FIN & ADM OFFICER                      251896.814500
# CHIEF-FACILITIES/OPERATIONS                  251898.146500
# CHIEF ACADEMIC OFFICER                       258191.449800
# SUPERINTENDENT OF SCHOOLS                    258355.610000
# CHIEF EXECUTIVE OFFICER                      294028.735800
# CHANCELLOR                                   302521.742300
# Superintendent                               351758.185600
# CLASSROOM TEACHERS - TITLE                   411325.546800
# TCHR, INTERVENTION SPEC (CC)                 473920.944800
# CLASSROOM TEACHERS - TITLE II A              514157.663500
# EDUCATIONAL AIDE I - Preschool Supplemental  845835.712100
# ACADMEY COORDINATOR                                    NaN
# ADMIN. AIDE                                            NaN
# ASBESTOS ABATEMENT SPEC                                NaN
# Budget Director                                        NaN
# COORDINATOR, SPEC ED                                   NaN
# Coordinator, Embsy Adopt Prog.                         NaN
# EDUCATIONAL AIDE HEADSTART                             NaN
# EDUCATIONAL AIDE, SPEC. ED.                            NaN
# EDUCATIONAL AIDE,80HS                                  NaN
# FOUNDATION GRANTS SPECIALIST                           NaN
# Network Administrator                                  NaN
# PIRNCIPAL, JHS                                         NaN
# PRINCIPAL,EC                                           NaN
# President Board Of Education                           NaN
# SPEC. EDUCATION COORDINATOR                            NaN
# SR. FINANCIAL SUPPORT ANALYST                          NaN
# STUDENT ATTENDANCE MANAGER                             NaN
# TCHR, FORNG LANG - CHINESE                             NaN
#
# [3516 rows x 1 columns]

# %%
average_total=train[['Total', 'Operating_Status']].groupby(['Operating_Status'], as_index = True).mean().sort_values(by = 'Total')
average_total.plot.bar(figsize = (10,8))
#plt.xticks(train['Function'].value)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
average_total=train[['Total', 'Object_Type']].groupby(['Object_Type'], as_index = True).mean().sort_values(by = 'Total')
average_total.plot.bar(figsize = (10,8))
#plt.xticks(train['Function'].value)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ave_total_func=train[['Total', 'Function']].groupby(['Function'], as_index = True).mean().sort_values(by = 'Total')
#df= pd.DataFrame(ave_total_func)
ave_total_func
# Out:
#                                                         Total
# Function
# Substitute Compensation                            640.000529
# Curriculum Development                            3454.453899
# Enrichment                                        3527.294352
# Extended Time & Tutoring                          4275.145614
# Instructional Materials & Supplies                4748.085582
# Recruitment                                       4963.837003
# Parent & Community Relations                      6813.885857
# Professional Development                          6824.458643
# Other Compensation                                6911.184866
# Other Non-Compensation                            7913.122474
# Aides Compensation                                8455.841231
# School Supervision                                8775.321746
# Student Transportation                            9792.324398
# Library & Media                                  10480.316285
# Facilities & Maintenance                         11000.273637
# Student Assignment                               11410.837263
# Food Services                                    13148.781273
# Physical Health & Services                       14402.120447
# Security & Safety                                16216.066484
# Social & Emotional                               16904.451223
# Human Resources                                  16927.147706
# Communications                                   17014.307764
# School Administration                            18152.452773
# Special Population Program Management & Support  18636.524307
# Career & Academic Counseling                     19735.692007
# Facilities Planning                              19945.523551
# Data Processing & Information Services           20459.341770
# Teacher Compensation                             20497.168418
# Research & Accountability                        21635.321488
# NO_LABEL                                         23384.100718
# Governance                                       25393.021018
# Finance, Budget, Purchasing & Distribution       26423.627491
# Untracked Budget Set-Aside                       33153.486445
# Legal                                            42297.154349
# Utilities                                        52557.000442
# Development & Fundraising                        59376.316701
# Insurance                                        61575.508947

# %%
ave_total_func.plot.bar()
#plt.xticks(train['Function'].value)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
g = sns.FacetGrid(train, col='Function')
g.map(plt.hist,ave_total_func, bins=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-2e244d4e9064> in <module>()
#       1 g = sns.FacetGrid(train, col='Function')
# ----> 2 g.map(plt.hist,ave_total_func.values, bins=10)
#
# /opt/conda/lib/python3.5/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     742
#     743             # Get the actual data we are going to plot with
# --> 744             plot_data = data_ijk[list(args)]
#     745             if self._dropna:
#     746                 plot_data = plot_data.dropna()
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1312                 # unique index
#    1313                 if labels.is_unique:
# -> 1314                     indexer = check = labels.get_indexer(objarr)
#    1315
#    1316                 # non-unique (dups)
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3239             target = target.astype(object)
#    3240             return this.get_indexer(target, method=method, limit=limit,
# -> 3241                                     tolerance=tolerance)
#    3242
#    3243         if not self.is_unique:
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3257                                  'backfill or nearest reindexing')
#    3258
# -> 3259             indexer = self._engine.get_indexer(target._ndarray_values)
#    3260
#    3261         return _ensure_platform_int(indexer)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 3)
